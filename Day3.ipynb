# %% [markdown]
# # EXERCISE 3

# %%
#Declare your age as integer variable
age = 24
#Declare your height as a float variable
height = 1.80
#Declare a variable that store a complex number
complex_num  = 2 + 4j
#Write a script that prompts the user to enter base and height of the triangle and calculate an area of this triangle (area = 0.5 x b x h).
height_tri= float (input(' Enter height of triangle: '))
base_tri= float (input(' Enter base of triangle: '))
Area = 0.5* base_tri * height_tri
print("The area of the triangle is: ", Area)

# %%
#Write a script that prompts the user to enter side a, side b, and side c of the triangle. Calculate the perimeter of the triangle (perimeter = a + b + c).

side_a = float(input('enter side a: '))
side_b = float(input('enter side b: '))
side_c = float(input('enter side c: '))

perimeter = side_a + side_b + side_c
print('The perimeter of the triangle is: ', perimeter)

# %%
#Get length and width of a rectangle using prompt.
#Calculate its area (area = length x width) and 
# perimeter (perimeter = 2 x (length + width))

length = float(input('enter length of the rectangle'))
width = float(input('enter width of the rectangle'))

Area_of_rectangle = length * width
perimeter_of_rectangle = 2*(length + width)

print('Area of the rectangle is: ',Area_of_rectangle )
print('perimeter of the rectangle is: ',perimeter_of_rectangle)

# %%
#Get radius of a circle using prompt. 
# Calculate the area (area = pi x r x r) and 
# circumference (c = 2 x pi x r) where pi = 3.14.

Radius = float(input('enter Radius of the rectangle'))
area_of_circle = 3.14*(Radius**2)
circumference = 3.14*2*Radius

print('area_of_circle is: ',area_of_circle)
print('circumference is: ',circumference)

# %%
#Calculate the slope, x-intercept and y-intercept of y = 2x -2
# given the equation y = 2x -2

slope = 2
y_intercept = -2
x_intercept = -(y_intercept/slope)

# %%
#Slope is (m = y2-y1/x2-x1). 
# Find the slope and Euclidean distance between point (2, 2) and point (6,10)
tup1 = (2, 2)
tup2 = (6,10)
slope = (tup2[1] - tup1[1])/(tup2[0]-tup1[0])

# %%
Euclidean_distance = (((tup2[0] -tup1[0])**2 + tup2[1]-tup1[1])**2)**(0.5)
print(Euclidean_distance)
# Out:
# 24.0

# %%
# Compare the slopes in tasks 8 and 9
print(slope == Euclidean_distance)
print(slope >= Euclidean_distance)
print(slope <= Euclidean_distance)
print(slope != Euclidean_distance)
# Out:
# False
# False
# True
# True

# %%
# Calculate the value of y (y = x^2 + 6x + 9). Try to use different x values and figure out at what x value y is going to be 0.
x = float(input("Enter a value for x: "))
y = (x**2)+(6*x)+9
print ("The value of y is :", y, "when the value of x is :", x)

# %%
# Find the length of 'python' and 'dragon' and make a falsy comparison statement.
python_len = len('python')
dragon_len = len('dragon')

print(python_len == dragon_len)
print(python_len != dragon_len)
print(python_len >= dragon_len)
print(python_len <= dragon_len)
# Out:
# True
# False
# True
# True

# %%
# Use and operator to check if 'on' is found in both 'python' and 'dragon'

'on' in 'python' and 'on' in 'dragon'
# Out:
# True

# %%
#I hope this course is not full of jargon. Use in operator to check if jargon is in the sentence.
print('jargon' in 'I hope this course is not full of jargon. Use in operator to check if jargon is in the sentence.')
# Out:
# True

# %%
#There is no 'on' in both dragon and python

# %%
# Find the length of the text python and convert the value to float and convert it to string

py_len = str(float(len('python')))
print(type(py_len))
# Out:
# <class 'str'>

# %%
# Even numbers are divisible by 2 and the remainder is zero. How do you check if a number is even or not using python?
x = int(input('put any number you want to check if even or odd: '))
if x%2 == 0:
    print(x,'is even number')
else:
    print(x,'is odd number')

# %%
#Check if the floor division of 7 by 3 is equal to the int converted value of 2.7.
(7//3) == int(2.7)
# Out:
# True

# %%
#Check if type of '10' is equal to type of 10
type('10') == type(10)
# Out:
# False

# %%
#Check if int('9.8') is equal to 10

#int('9.8') == 10 this will rsie an error because the value 9.8 as string cant be changed to integer directly
# so we change it to decimal first then we conver it to integer, we do this to compare number with number

int(float(9.8)) == 10
# Out:
# False

# %%
# Out:
# 9

# %%
#Write a script that prompts the user to enter hours and rate per hour. Calculate pay of the person?
#Enter hours: 40
#Enter rate per hour: 28
#Your weekly earning is 1120

num_of_hour = int(input('enter number of hours worked per week:'))
num_of_rate = float(input('enter the rate employe is paid per hour'))

weekly_pay = num_of_hour*num_of_rate

print('the weekly salary of the employe is ', weekly_pay)

# %%
# Write a script that prompts the user to enter number of years. Calculate the number of seconds a person can live. Assume a person can live hundred years
Age = 100
number_of_seconds_lived = Age*365.25*24*60*60
print('number_of_seconds_lived is', number_of_seconds_lived)
# Out:
# number_of_seconds_lived is 3155760000.0

# %%
#this is the easy and short mathematical way 
for i in range (1,6):
    print(i,i**0,i*1,i**2,i**3)
# Out:
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125

# %%
# the long way also works 
print(1,1,1,1,1)
print(2,1,2,4,8)
print(3,1,3,9,27)
print(4,1,4,16,64)
print(5,1,5,25,125)
# Out:
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125

# %% [markdown]
# # Day 3 completed succesfully
