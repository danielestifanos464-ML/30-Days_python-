# %% [markdown]
# # <Center>Day18</Center>

# %%
#What is the most frequent word in the following paragraph?
paragraph = 'I love teaching. If you do not love teaching what else can you love. I love Python if you do not love something which can give you all the capabilities to develop an application what else can you love.'

import re

def count_(x):
    list_ = re.findall('[a-zA-z]+',x,re.I)
    dict_ = {}
    for i in list_:
        count = 0 
        if i in dict_:
            dict_[i]+=1
        else:
            dict_[i] = 1
    return  dict_.items()

print(count_(paragraph))
# Out:
# dict_items([('I', 2), ('love', 6), ('teaching', 2), ('If', 1), ('you', 5), ('do', 2), ('not', 2), ('what', 2), ('else', 2), ('can', 3), ('Python', 1), ('if', 1), ('something', 1), ('which', 1), ('give', 1), ('all', 1), ('the', 1), ('capabilities', 1), ('to', 1), ('develop', 1), ('an', 1), ('application', 1)])

# %%
#The position of some particles on the horizontal x-axis are -12, -4, -3 and -1 in the negative direction, 0 at origin, 4 and 8 in the positive direction. Extract these numbers from this whole text and find the distance between the two furthest particles.
points = ['-12', '-4', '-3', '-1', '0', '4', '8']
sorted_points =  [-12, -4, -3, -1, -1, 0, 2, 4, 8]

points_range = int(points[-1]) - int(points[0])
print("points_range:",points_range)

sorted_points_range = int(sorted_points[-1]) - int(sorted_points[0])
print("sorted_points_range: ",sorted_points_range)
# Out:
# points_range: 20
# sorted_points_range:  20

# %%
#Write a pattern which identifies if a string is a valid python variable

def valid_python_var(var):
   return var.isidentifier()
# Out:
# True

# %%
sentence = '''%I $am@% a %tea@cher%, &and& I lo%#ve %tea@ching%;. There $is nothing; &as& mo@re rewarding as educa@ting &and& @emp%o@wering peo@ple. ;I found tea@ching m%o@re interesting tha@n any other %jo@bs. %Do@es thi%s mo@tivate yo@u to be a tea@cher!?'''
regex = r"[%$@&#?!;.,]"
new_sentence = re.sub(regex,"",sentence)
new_sentence
# Out:
# 'I am a teacher and I love teaching There is nothing as more rewarding as educating and empowering people I found teaching more interesting than any other jobs Does this motivate you to be a teacher'

# %% [markdown]
# <center><h1 >Day18 Completed!!!<h/1></center>
