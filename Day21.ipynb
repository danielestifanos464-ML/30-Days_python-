# %% [markdown]
# # <center>Day21 <center>

# %% [markdown]
# ```sh
# ages = [31, 26, 34, 37, 27, 26, 32, 32, 26, 27, 27, 24, 32, 33, 27, 25, 26, 38, 37, 31, 34, 24, 33, 29, 26]
#
# print('Count:', data.count()) # 25
# print('Sum: ', data.sum()) # 744
# print('Min: ', data.min()) # 24
# print('Max: ', data.max()) # 38
# print('Range: ', data.range()) # 14
# print('Mean: ', data.mean()) # 30
# print('Median: ', data.median()) # 29
# print('Mode: ', data.mode()) # {'mode': 26, 'count': 5}
# print('Standard Deviation: ', data.std()) # 4.2
# print('Variance: ', data.var()) # 17.5
# print('Frequency Distribution: ', data.freq_dist()) # [(20.0, 26), (16.0, 27), (12.0, 32), (8.0, 37), (8.0, 34), (8.0, 33), (8.0, 31), (8.0, 24), (4.0, 38), (4.0, 29), (4.0, 25)]
#
# ```

# %%
import statistics as st
ages = [31, 26, 34, 37, 27, 26, 32, 32, 26, 27, 27, 24, 32, 33, 27, 25, 26, 38, 37, 31, 34, 24, 33, 29]
class Statistics_Estif:
    def __init__(self,list_a):
        self.list_a = list_a
    def count(self):
        return len(self.list_a)
    def sum(self):
        return sum(self.list_a)
    def min(self):
        return min(self.list_a)
    def max(self):
        return max(self.list_a)
    def range(self):
        return self.max() - self.min()
    def mean(self):
        return self.sum()/self.count()
    def median(self):
        n = self.count()
        sorted_list = sorted(self.list_a)

        if n%2 == 0:
            mid1 = sorted_list[n//2]
            mid2= sorted_list[n//2 -1]
            return (mid2+mid1)/2
        else:
            return sorted_list[n//2]
    def mode(self):
        dic_mode = {}
        for i in self.list_a:
            if i in dic_mode:
                dic_mode[i] +=1 
            else:
                dic_mode[i] = 1
        m = max(dic_mode.values())
        modes = [k for k,v in dic_mode.items() if v==m]
        return modes
    # the rest we will ue the module statstcs to create them 
    def stand_dev(self):
        return st.stdev(self.list_a)
    def var(self):
        return st.variance(self.list_a)
    def freq_dist(self):
        dic_mode = {}
        for i in self.list_a:
            if i in dic_mode:
                dic_mode[i] +=1 
            else:
                dic_mode[i] = 1
        
        return list(dic_mode.items())

# %% [markdown]
# ```sh
# Create a class called PersonAccount. It has firstname, lastname, incomes, expenses properties and it has total_income, total_expense, account_info, add_income, add_expense and account_balance methods. Incomes is a set of incomes and its description. The same goes for expenses.
# ```

# %%
class PersonAccount:
    def __init__(self,firstname ='Estifanos', lastname = 'Daniel', incomes = None, expenses = None):
        self.firstname = firstname
        self.lastname = lastname
        self.income = incomes if incomes is not None else {}
        self.expenses = expenses if expenses is not None else {}
    def add_income(self,description,income):
        self.income[description] = income
    def add_expense(self,description,expense):
        self.expenses[description] = expense
    def total_income(self):
        return sum(self.income.values())
    def total_expense(self):
        return sum(self.expenses.values())
    def account_info(self):
        return f'This account belongs to {self.firstname} {self.lastname}' 
    def account_balance(self):
        return self.total_income() - self.total_expense()

# %% [markdown]
# # <center> Day21 Completed!!! <center>
