# %% [markdown]
# # <center>Day 5</center>

# %%
#Declare an empty list
empty_list = []

#Declare a list with more than 5 items
first_list = ['Asmara','Massawa','Keren', 'Tesenei','Decemhare']

#Find the length of your list
print('length of the empty list is',len(empty_list))
print('Length of the first list is',len(first_list))

#Get the first item, the middle item and the last item of the list
print(first_list[0],first_list[2],first_list[-1])

#Declare a list called mixed_data_types, put your(name, age, height, marital status, address)
mixed_data_types = ['Estifanos',24,180,'Single','Asmara']

#Declare a list variable named it_companies and assign initial values Facebook, Google, Microsoft, Apple, IBM, Oracle and Amazon.
it_companies = ['Facebook','Google','Microsoft','Apple','IBM','Oracle','Amazon']

#Print the list using print()
print(it_companies)

#Print the number of companies in the list
print(len(it_companies))

#Print the first, middle and last company
print(it_companies[0],it_companies[3],it_companies[-1])

#Print the list after modifying one of the companies
it_companies[0] = 'Meta'
#Add an IT company to it_companies
it_companies.append('SAP')
# Out:
# length of the empty list is 0
# Length of the first list is 5
# Asmara Keren Decemhare
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']
# 7
# Facebook Apple Amazon

# %%
#Insert an IT company in the middle of the companies list
it_companies.insert(5,'Eri_tech')

#Change one of the it_companies names to uppercase (IBM excluded!)
it_companies[0] = it_companies[0].upper()

#Join the it_companies with a string '#;  '
print(' #'.join(it_companies))

#Check if a certain company exists in the it_companies list.
print('IBM' in it_companies)

#Sort the list using sort() method
it_companies.sort()
#Reverse the list in descending order using reverse() method
it_companies.sort(reverse = True)
#Slice out the first 3 companies from the list
print(it_companies[0:3])
#Slice out the last 3 companies from the list
print(it_companies[-3:])
#Slice out the middle IT company or companies from the list
it_companies[3:5]
# Out:
# META #Google #Microsoft #Apple #IBM #Eri_tech #Oracle #Amazon #SAP
# True
# ['SAP', 'Oracle', 'Microsoft']
# ['Eri_tech', 'Apple', 'Amazon']
# ['META', 'IBM']

# %%
#Remove the first IT company from the list
it_companies.remove('SAP')
#Remove the middle IT company or companies from the list
it_companies.remove('META')
#Remove the last IT company from the list
it_companies.pop(-1)
#Remove all IT companies from the list
it_companies.clear()
#Destroy the IT companies list
del it_companies

# %%
print(it_companies)# will raise an error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 print(it_companies)
#
# NameError: name 'it_companies' is not defined

# %%
#Join the following lists:

#front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
#back_end = ['Node','Express', 'MongoDB']
#After joining the lists in question 26. Copy the joined list and assign it to a variable full_stack, then insert Python and SQL after Redux.

# %%
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node','Express', 'MongoDB']

front_end.extend(back_end)
front_end.extend(['Python','SQL'])
full_stack = front_end
print(full_stack)
# Out:
# ['HTML', 'CSS', 'JS', 'React', 'Redux', 'Node', 'Express', 'MongoDB', 'Python', 'SQL']

# %% [markdown]
# ## Exersice 2

# %% [markdown]
# The following is a list of 10 students ages:
#
# ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]
#
# - Sort the list and find the min and max age
# - Add the min age and the max age again to the list
# - Find the median age (one middle item or two middle items divided by two)
# - Find the average age (sum of all items divided by their number )
# - Find the range of the ages (max minus min)
# - Compare the value of (min - average) and (max - average), use abs() method
# - Find the middle country(ies) in the countries list
# - Divide the countries list into two equal lists if it is even if not one more country for the first half.
# - ['China', 'Russia', 'USA', 'Finland', 'Sweden', 'Norway', 'Denmark']. Unpack the first three countries and the rest as scandic countries.

# %%
ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]
#Sort the list and find the min and max age
ages.sort()
print('Maximum age',max(ages),'Minimum age',min(ages))

#Add the min age and the max age again to the list

ages.extend([max(ages),min(ages)])
print(ages)

#Find the median age (one middle item or two middle items divided by two)
ages.sort()
n = len(ages)

if n %2 == 0:
    print('median is',
           (ages[n//2] + ages[(n//2)+1])/2
    )
else:
    print(
        'median is',
        ages[(n+1)//2]
        
    )
# Find the average age (sum of all items divided by their number )
Average = sum(ages)/len(ages)
print(Average)

#Find the range of the ages (max minus min)
range = max(ages) - min(ages)
print(range)

#Compare the value of (min - average) and (max - average), use abs() method

Age_minmum = min(ages)
Age_maximum = max(ages)

min_A = abs(Age_minmum - Average)
max_A = abs(Age_maximum - Average)

if min_A > max_A:
    print('min - average is greater than max - average')

else:
    print('max - average is greater than min - average ')
# Out:
# Maximum age 26 Minimum age 19
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26, 26, 19]
# median is 24.0
# 22.75
# 7
# min - average is greater than max - average

# %%
#Divide the countries list into two equal lists if it is even if not one more country for the first half.
#['China', 'Russia', 'USA', 'Finland', 'Sweden', 'Norway', 'Denmark']. 

countries = ['China', 'Russia', 'USA', 'Finland', 'Sweden', 'Norway', 'Denmark']

print(countries[0:4])
print(countries[4:])

#Unpack the first three countries 
First_country,second_country,thirid_country,*rest = countries
print(First_country,second_country,thirid_country)
# Out:
# ['China', 'Russia', 'USA', 'Finland']
# ['Sweden', 'Norway', 'Denmark']
# China Russia USA

# %% [markdown]
# # <center>Day 5 completed!!!</center>
