# %% [markdown]
# # <center>Day 17</center>

# %%
#names = ['Finland', 'Sweden', 'Norway','Denmark','Iceland', 'Estonia','Russia']. Unpack the first five countries and store them in a variable nordic_countries, store Estonia and Russia in es, and ru respectively.
names = ['Finland', 'Sweden', 'Norway','Denmark','Iceland', 'Estonia','Russia']

# %%
*first,second,third = names
nordic_countries= first
es = second
ru = third
print("nordic_countries: ",nordic_countries,"\nes: ",es,"\nru: ",ru)
# Out:
# nordic_countries:  ['Finland', 'Sweden', 'Norway', 'Denmark', 'Iceland']
# es:  Estonia
# ru:  Russia

# %% [markdown]
# # <center>Day17!!! Completed</center>
