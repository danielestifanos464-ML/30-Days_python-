# %% [markdown]
# ```sh
# 1. Books to Scrape (YOU ARE ALREADY USING IT)
#
# url = http://books.toscrape.com/
#
# -Products (title, price, rating)
# -Categories
# -Pagination (multiple pages)
# ```
# ===========================================================================================================
#
# ```sh
# 2. Quotes to Scrape
# url = http://quotes.toscrape.com/
# Practice:
# Text extraction
# Authors
# Tags
# Pagination
# Login scraping (advanced)
# ```
# ===========================================================================================================
#
# ```sh
# Scrape This Site (VERY IMPORTANT)
#
# url = https://www.scrapethissite.com/pages/
# Practice:
# Tables
# Multiple pages
# Real challenges
# Structured datasets
# *Simulates real-world scraping
# ```
# ===========================================================================================================
#
# ```sh
# 4. Wikipedia (Real-world practice)
# url = https://en.wikipedia.org/
# Practice:
# Tables
# Links
# Large structured data
# ```
# ===========================================================================================================
# ```sh
# 5. Yahoo Finance (Advanced)
# url = https://finance.yahoo.com/
# Practice:
# Tables
# Dynamic data
# Real-world datasets
# ```
